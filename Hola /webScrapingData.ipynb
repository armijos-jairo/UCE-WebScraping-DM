# %% [markdown]
# # **EXTRACCIÓN DE DATOS**
# *   **Autor:** "Jairo Armijos"
# *   **Fecha:** "19/12/2023"
# *   **Título:** "Extracción de datos de la Web (Scrapy)"
# *   **Tema:** "Clasificación de desempeño de artículos científicos para universidades del mundo"

# %% [markdown]
# # **1. Pre Requisitos**

# %%
# Instalación de las librerias o dependencias necesarias
# !pip install beautifulsoup4 requests pandas

# %%
# Dependencias de carga
import json # Modulo para trabajar con archivos JSON
import requests # Libreria para hacer peticiones HTTP
import pandas as pd # Libreria para procesar datos, proporciona funciones para analíticas
from bs4 import BeautifulSoup as bs # Extraer información de paginas web

# %% [markdown]
# # **2. Funciones para procesamiento de los datos**

# %%
# Función que convierte una lista de elementos en un dataframe de pandas
def rowsToDataFrame(rows):
    df = pd.DataFrame(rows[1:], columns=rows[0])
    return df

# %%
# Función para extraer los datos de una tabla HTML
def processTableData(tbl):
    rows = []
    for child in tbl.find('tbody').children: # Itera los items internos de la tabla [<tr>]
        row = []
        for td in child: # Itera los items internos de la tabla [<td>]
            try:
                item = td.text.replace('\n', '') # Recupera el texto del elemento [<td>]
                if item:
                    row.append(item) # Agrega cada elemento de la fila
            except:
                continue
        if len(row) > 0:
            rows.append(row) # Agrega todos los campos de una fila de la tabla
    # print(rows)
    return rows

# %%
# Función para extraer la data de la URL y procesar el contenido HTML
def processDataHTML(data):
    soup = bs(data['sections'][1]['text'], 'html.parser') # Recupera el item del JSON y lo convierte en contenido HTML
    tbl = soup.find_all('table')[0] # Recupera la tabla del contenido HTML
    # print(tbl.prettify())
    tblRows = processTableData(tbl) # Ejecuta la función para procesar el contenido de la Tabla
    return tblRows

# %% [markdown]
# # **3. Extracción de Información**

# %%
# Leer sitio web
r = requests.get('https://www.wikiwand.com/mcs-api/en.wikipedia.org/v1/page/mobile-sections-remaining/Performance_Ranking_of_Scientific_Papers_for_World_Universities')  # Recuperamos el contenido de la web
# print(r)
table = processDataHTML(json.loads(r.content)) # Formate el contenido en formato JSON
df = rowsToDataFrame(table) # Ejecuta la funcion para recupera los datos de la tabla como dataframe de Pandas
df
# Out:
#    2010 2009 2008 2007                                    Institution  \
# 0     1    1    1    1                             Harvard University
# 1     2    3    3    4                            Stanford University
# 2     3    2    2    2                       Johns Hopkins University
# 3     4    4    4    3                       University of Washington
# 4     5    5    5    5          University of California, Los Angeles
# 5     6    8    6    7             University of California, Berkeley
# 6     7    7    7   10          Massachusetts Institute of Technology
# 7     8    6    7    6                         University of Michigan
# 8     9   11   14   12                          University of Toronto
# 9    10   17   19   19                           University of Oxford
# 10   11    9   11   11                     University of Pennsylvania
# 11   12   13   10    8            University of California, San Diego
# 12   13   10   13    9                            Columbia University
# 13   14   14   12   13                            University of Tokyo
# 14   15   12    9   15        University of California, San Francisco
# 15   16   15   16   17                        University of Cambridge
# 16   17   20   20   24                      University College London
# 17   18   16   15   14                                Yale University
# 18   19   18   17   16                                Duke University
# 19   20   25   21   20                University of Wisconsin–Madison
# 20   21   22   27   28                        Imperial College London
# 21   22   19   18   18                             Cornell University
# 22   23   24   22   21                       University of Pittsburgh
# 23   24   21   23   22                        University of Minnesota
# 24   25   23   26   25             Washington University in St. Louis
# 25   26   27   25   23    University of North Carolina at Chapel Hill
# 26   27   26   30   29                        Northwestern University
# 27   28   28   28   27                               Kyoto University
# 28   29   32   32   35                University of California, Davis
# 29   30   29   24   26                          University of Chicago
# 30   31   30   31   32             California Institute of Technology
# 31   32   31   33   39                 University of British Columbia
# 32   33   33   35   30                          Ohio State University
# 33   34   34   36   50                          Karolinska Institutet
# 34   35   36   34   36                              McGill University
# 35   36   46   44   41     University of Illinois at Urbana–Champaign
# 36   37   43   45   54                               Emory University
# 37   38   35   38   40                               Osaka University
# 38   39   38   42   48                           Princeton University
# 39   40   47   43   44                          University of Florida
# 40   41   44   52   33  University of Texas MD Anderson Cancer Center
# 41   42   40   29   31                  Pennsylvania State University
# 42   43   51   58   64                        University of Melbourne
# 43   44   42   47   46         Ludwig Maximilian University of Munich
# 44   45   45   41   43                            New York University
# 45   46   48   63   37                Mayo Clinic College of Medicine
# 46   47   48   50   52                         University of Helsinki
# 47   48   57   46   45                          Vanderbilt University
# 48   49   56   53   56                             Utrecht University
# 49   49   40   37   38                          University of Arizona
#
#            Country
# 0    United States
# 1    United States
# 2    United States
# 3    United States
# 4    United States
# 5    United States
# 6    United States
# 7    United States
# 8           Canada
# 9   United Kingdom
# 10   United States
# 11   United States
# 12   United States
# 13           Japan
# 14   United States
# 15  United Kingdom
# 16  United Kingdom
# 17   United States
# 18   United States
# 19   United States
# 20  United Kingdom
# 21   United States
# 22   United States
# 23   United States
# 24   United States
# 25   United States
# 26   United States
# 27           Japan
# 28   United States
# 29   United States
# 30   United States
# 31          Canada
# 32   United States
# 33          Sweden
# 34          Canada
# 35   United States
# 36   United States
# 37           Japan
# 38   United States
# 39   United States
# 40   United States
# 41   United States
# 42       Australia
# 43         Germany
# 44   United States
# 45   United States
# 46         Finland
# 47   United States
# 48     Netherlands
# 49   United States

# %%
# Inspeccionamos el tipo de dato de cada variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   2010         50 non-null     object
#  1   2009         50 non-null     object
#  2   2008         50 non-null     object
#  3   2007         50 non-null     object
#  4   Institution  50 non-null     object
#  5   Country      50 non-null     object
# dtypes: object(6)
# memory usage: 2.5+ KB

# %% [markdown]
# # **4. Almacenamiento de los datos**

# %%
# Guardamos las datos extraidos como archivo CSV
df.to_csv('rankingScientificPapers.csv')

# %% [markdown]
# # **5. Referencia**
#
# *   [Ranking basado en campos](https://www.wikiwand.com/en/Performance_Ranking_of_Scientific_Papers_for_World_Universities)
